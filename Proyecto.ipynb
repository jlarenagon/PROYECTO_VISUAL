# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Obesity_DataSet_2.csv')
df
# Out:
#          BMI_WHO  Age  Gender    Race1       Education     HHIncome  \
# 0          Obese   34    male    White     High School  25000-34999
# 1          Obese   34    male    White     High School  25000-34999
# 2          Obese   34    male    White     High School  25000-34999
# 3          Obese   49  female    White    Some College  35000-44999
# 4     OverWeight   45  female    White    College Grad  75000-99999
# ...          ...  ...     ...      ...             ...          ...
# 7476  OverWeight   28    male  Mexican  9 - 11th Grade    5000-9999
# 7477  OverWeight   28    male  Mexican  9 - 11th Grade    5000-9999
# 7478       Obese   27    male  Mexican    College Grad  75000-99999
# 7479  OverWeight   60    male    White    College Grad  65000-74999
# 7480  OverWeight   60    male    White    College Grad  65000-74999
#
#      PhysActive Smoke100 Diabetes  BPSysAve  TotChol Alcohol12PlusYr  \
# 0            No      Yes       No     113.0     3.49             Yes
# ...
